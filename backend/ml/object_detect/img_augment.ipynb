# %%
#import cv2
import numpy as np
import matplotlib.pyplot as plt
import random

from skimage import data, color, io, img_as_ubyte
from skimage.transform import rescale, resize, downscale_local_mean, rotate

import os
#from os import listdir
from os.path import isfile, join

# %% [markdown]
# ## Functions to augment the images

# %%
def augment_w(img, ratio_w):

    h, w = img.shape[:2]

    w_to_shift = int(w * ratio_w)


    align_shift_r = w-w_to_shift-1
    align_shift_l = w_to_shift+1


    h_to_crop = int((h - align_shift_r * 3) / 2)
    h_to_crop_btm = h-h_to_crop

    if (h - align_shift_r * 3) % 2 == 0:
        h_to_crop_btm = h-h_to_crop
    else:
        h_to_crop_btm = h-h_to_crop-1
   
    img_new_r = img[h_to_crop: h_to_crop_btm, :align_shift_r, :]
    img_new_l = img[h_to_crop: h_to_crop_btm, align_shift_l:, :]

    #print(h_to_crop-1, h_to_crop_btm)
    #print(img.shape)
    #print(img_new_r.shape)
    #print(img_new_l.shape)

    return [img_new_r, img_new_l]



def augment_h(img, ratio_h):
    h, w = img.shape[:2]
    
    h_to_shift = int(h * ratio_h)

    align_shift_b = (int((h-h_to_shift)/3)) * 3

    align_shift_t = h - align_shift_b

    w_to_crop = int((w - align_shift_b / 3) / 2)

    
    if (w - align_shift_b / 3) % 2 == 0:
        w_to_crop_btm = w-w_to_crop
    else:
        w_to_crop_btm = w-w_to_crop-1


    img_new_t = img[align_shift_t:, w_to_crop:w_to_crop_btm, :]
    img_new_b = img[:align_shift_b, w_to_crop:w_to_crop_btm, :]

    
    return [img_new_t, img_new_b]

# %% [markdown]
# ## Functions to rotate the images

# %%
def rotate_uint8(img, degree):
    return (rotate(img, 180) * 255).astype(np.uint8)

# %% [markdown]
# ## IO and function calls

# %%
def augment_rotate_ds(in_file_path, out_file_path, ratio_w, ratio_h):
    
    files_list = [f for f in os.listdir(in_file_path) if isfile(join(in_file_path, f))]
    
    for f in files_list:
        img = io.imread(in_file_path + "\\"+ f)

        img_new_r, img_new_l = augment_w(img, ratio_w)
        img_new_t, img_new_b = augment_h(img, ratio_h)

        # 180 degree rotate
        img_new_flip_r = rotate_uint8(img_new_r, 180)
        img_new_flip_l = rotate_uint8(img_new_l, 180)
        img_new_flip_t = rotate_uint8(img_new_t, 180)
        img_new_flip_b = rotate_uint8(img_new_b, 180)


        f_split = os.path.splitext((out_file_path + "/"+ f))

        print(f_split[0] + '_r' + '.jpg')
        print(f_split[0] + '_l' + '.jpg')
        print(f_split[0] + '_t' + '.jpg')
        print(f_split[0] + '_b' + '.jpg')


        io.imsave(f_split[0] + '_r' + '.jpg', img_new_r)
        io.imsave(f_split[0] + '_l' + '.jpg', img_new_l)
        io.imsave(f_split[0] + '_t' + '.jpg', img_new_t)
        io.imsave(f_split[0] + '_b' + '.jpg', img_new_b)

        io.imsave(f_split[0] + '_r_flip' + '.jpg', img_new_flip_r)
        io.imsave(f_split[0] + '_l_flip' + '.jpg', img_new_flip_l)
        io.imsave(f_split[0] + '_t_flip' + '.jpg', img_new_flip_t)
        io.imsave(f_split[0] + '_b_flip' + '.jpg', img_new_flip_b)

        
def rotate_ds(in_file_path, out_file_path):
    
    files_list = [f for f in os.listdir(in_file_path) if isfile(join(in_file_path, f))]
    
    for f in files_list:
        img = io.imread(in_file_path + "\\"+ f)
        img_new_flip = rotate_uint8(img, 180)
        
        f_split = os.path.splitext((out_file_path + "/"+ f))
        
        print(f_split[0] + '_r_flip' + '.jpg')
        io.imsave(f_split[0] + '_r_flip' + '.jpg', img_new_flip)

# %% [markdown]
# Writing the augmented images into directory

# %%
img_org_path0 = './images/lateral/tabasom/cropped'
img_new_path0 = './images/lateral/tabasom/cropped/augmented'

img_org_path1 = './images/lateral/hcng/cropped'
img_new_path1 = './images/lateral/hcng/cropped/augmented'


augment_rotate_ds(img_org_path0, img_new_path0, 0.2, 0.16)
# Out:
# ./images/lateral/tabasom/cropped/augmented/1_r.jpg
# ./images/lateral/tabasom/cropped/augmented/1_l.jpg
# ./images/lateral/tabasom/cropped/augmented/1_t.jpg
# ./images/lateral/tabasom/cropped/augmented/1_b.jpg
# ./images/lateral/tabasom/cropped/augmented/10_r.jpg
# ./images/lateral/tabasom/cropped/augmented/10_l.jpg
# ./images/lateral/tabasom/cropped/augmented/10_t.jpg
# ./images/lateral/tabasom/cropped/augmented/10_b.jpg
# ./images/lateral/tabasom/cropped/augmented/11_r.jpg
# ./images/lateral/tabasom/cropped/augmented/11_l.jpg
# ./images/lateral/tabasom/cropped/augmented/11_t.jpg
# ./images/lateral/tabasom/cropped/augmented/11_b.jpg
# ./images/lateral/tabasom/cropped/augmented/12_r.jpg
# ./images/lateral/tabasom/cropped/augmented/12_l.jpg
# ./images/lateral/tabasom/cropped/augmented/12_t.jpg
# ./images/lateral/tabasom/cropped/augmented/12_b.jpg
# ./images/lateral/tabasom/cropped/augmented/13_r.jpg
# ./images/lateral/tabasom/cropped/augmented/13_l.jpg
# ./images/lateral/tabasom/cropped/augmented/13_t.jpg
# ./images/lateral/tabasom/cropped/augmented/13_b.jpg
# ./images/lateral/tabasom/cropped/augmented/14_r.jpg
# ./images/lateral/tabasom/cropped/augmented/14_l.jpg
# ./images/lateral/tabasom/cropped/augmented/14_t.jpg
# ./images/lateral/tabasom/cropped/augmented/14_b.jpg
# ./images/lateral/tabasom/cropped/augmented/15_r.jpg
# ./images/lateral/tabasom/cropped/augmented/15_l.jpg
# ./images/lateral/tabasom/cropped/augmented/15_t.jpg
# ./images/lateral/tabasom/cropped/augmented/15_b.jpg
# ./images/lateral/tabasom/cropped/augmented/16_r.jpg
# ./images/lateral/tabasom/cropped/augmented/16_l.jpg
# ./images/lateral/tabasom/cropped/augmented/16_t.jpg
# ./images/lateral/tabasom/cropped/augmented/16_b.jpg
# ./images/lateral/tabasom/cropped/augmented/17_r.jpg
# ./images/lateral/tabasom/cropped/augmented/17_l.jpg
# ./images/lateral/tabasom/cropped/augmented/17_t.jpg
# ./images/lateral/tabasom/cropped/augmented/17_b.jpg
# ./images/lateral/tabasom/cropped/augmented/18_r.jpg
# ./images/lateral/tabasom/cropped/augmented/18_l.jpg
# ./images/lateral/tabasom/cropped/augmented/18_t.jpg
# ./images/lateral/tabasom/cropped/augmented/18_b.jpg
# ./images/lateral/tabasom/cropped/augmented/19_r.jpg
# ./images/lateral/tabasom/cropped/augmented/19_l.jpg
# ./images/lateral/tabasom/cropped/augmented/19_t.jpg
# ./images/lateral/tabasom/cropped/augmented/19_b.jpg
# ./images/lateral/tabasom/cropped/augmented/2_r.jpg
# ./images/lateral/tabasom/cropped/augmented/2_l.jpg
# ./images/lateral/tabasom/cropped/augmented/2_t.jpg
# ./images/lateral/tabasom/cropped/augmented/2_b.jpg
# ./images/lateral/tabasom/cropped/augmented/20_r.jpg
# ./images/lateral/tabasom/cropped/augmented/20_l.jpg
# ./images/lateral/tabasom/cropped/augmented/20_t.jpg
# ./images/lateral/tabasom/cropped/augmented/20_b.jpg
# ./images/lateral/tabasom/cropped/augmented/21_r.jpg
# ./images/lateral/tabasom/cropped/augmented/21_l.jpg
# ./images/lateral/tabasom/cropped/augmented/21_t.jpg
# ./images/lateral/tabasom/cropped/augmented/21_b.jpg
# ./images/lateral/tabasom/cropped/augmented/22_r.jpg
# ./images/lateral/tabasom/cropped/augmented/22_l.jpg
# ./images/lateral/tabasom/cropped/augmented/22_t.jpg
# ./images/lateral/tabasom/cropped/augmented/22_b.jpg
# ./images/lateral/tabasom/cropped/augmented/23_r.jpg
# ./images/lateral/tabasom/cropped/augmented/23_l.jpg
# ./images/lateral/tabasom/cropped/augmented/23_t.jpg
# ./images/lateral/tabasom/cropped/augmented/23_b.jpg
# ./images/lateral/tabasom/cropped/augmented/24_r.jpg
# ./images/lateral/tabasom/cropped/augmented/24_l.jpg
# ./images/lateral/tabasom/cropped/augmented/24_t.jpg
# ./images/lateral/tabasom/cropped/augmented/24_b.jpg
# ./images/lateral/tabasom/cropped/augmented/25_r.jpg
# ./images/lateral/tabasom/cropped/augmented/25_l.jpg
# ./images/lateral/tabasom/cropped/augmented/25_t.jpg
# ./images/lateral/tabasom/cropped/augmented/25_b.jpg
# ./images/lateral/tabasom/cropped/augmented/26_r.jpg
# ./images/lateral/tabasom/cropped/augmented/26_l.jpg
# ./images/lateral/tabasom/cropped/augmented/26_t.jpg
# ./images/lateral/tabasom/cropped/augmented/26_b.jpg
# ./images/lateral/tabasom/cropped/augmented/27_r.jpg
# ./images/lateral/tabasom/cropped/augmented/27_l.jpg
# ./images/lateral/tabasom/cropped/augmented/27_t.jpg
# ./images/lateral/tabasom/cropped/augmented/27_b.jpg
# ./images/lateral/tabasom/cropped/augmented/28_r.jpg
# ./images/lateral/tabasom/cropped/augmented/28_l.jpg
# ./images/lateral/tabasom/cropped/augmented/28_t.jpg
# ./images/lateral/tabasom/cropped/augmented/28_b.jpg
# ./images/lateral/tabasom/cropped/augmented/29_r.jpg
# ./images/lateral/tabasom/cropped/augmented/29_l.jpg
# ./images/lateral/tabasom/cropped/augmented/29_t.jpg
# ./images/lateral/tabasom/cropped/augmented/29_b.jpg
# ./images/lateral/tabasom/cropped/augmented/3_r.jpg
# ./images/lateral/tabasom/cropped/augmented/3_l.jpg
# ./images/lateral/tabasom/cropped/augmented/3_t.jpg
# ./images/lateral/tabasom/cropped/augmented/3_b.jpg
# ./images/lateral/tabasom/cropped/augmented/30_r.jpg
# ./images/lateral/tabasom/cropped/augmented/30_l.jpg
# ./images/lateral/tabasom/cropped/augmented/30_t.jpg
# ./images/lateral/tabasom/cropped/augmented/30_b.jpg
# ./images/lateral/tabasom/cropped/augmented/31_r.jpg
# ./images/lateral/tabasom/cropped/augmented/31_l.jpg
# ./images/lateral/tabasom/cropped/augmented/31_t.jpg
# ./images/lateral/tabasom/cropped/augmented/31_b.jpg
# ./images/lateral/tabasom/cropped/augmented/32_r.jpg
# ./images/lateral/tabasom/cropped/augmented/32_l.jpg
# ./images/lateral/tabasom/cropped/augmented/32_t.jpg
# ./images/lateral/tabasom/cropped/augmented/32_b.jpg
# ./images/lateral/tabasom/cropped/augmented/33_r.jpg
# ./images/lateral/tabasom/cropped/augmented/33_l.jpg
# ./images/lateral/tabasom/cropped/augmented/33_t.jpg
# ./images/lateral/tabasom/cropped/augmented/33_b.jpg
# ./images/lateral/tabasom/cropped/augmented/34_r.jpg
# ./images/lateral/tabasom/cropped/augmented/34_l.jpg
# ./images/lateral/tabasom/cropped/augmented/34_t.jpg
# ./images/lateral/tabasom/cropped/augmented/34_b.jpg
# ./images/lateral/tabasom/cropped/augmented/35_r.jpg
# ./images/lateral/tabasom/cropped/augmented/35_l.jpg
# ./images/lateral/tabasom/cropped/augmented/35_t.jpg
# ./images/lateral/tabasom/cropped/augmented/35_b.jpg
# ./images/lateral/tabasom/cropped/augmented/36_r.jpg
# ./images/lateral/tabasom/cropped/augmented/36_l.jpg
# ./images/lateral/tabasom/cropped/augmented/36_t.jpg
# ./images/lateral/tabasom/cropped/augmented/36_b.jpg
# ./images/lateral/tabasom/cropped/augmented/37_r.jpg
# ./images/lateral/tabasom/cropped/augmented/37_l.jpg
# ./images/lateral/tabasom/cropped/augmented/37_t.jpg
# ./images/lateral/tabasom/cropped/augmented/37_b.jpg
# ./images/lateral/tabasom/cropped/augmented/38_r.jpg
# ./images/lateral/tabasom/cropped/augmented/38_l.jpg
# ./images/lateral/tabasom/cropped/augmented/38_t.jpg
# ./images/lateral/tabasom/cropped/augmented/38_b.jpg
# ./images/lateral/tabasom/cropped/augmented/39_r.jpg
# ./images/lateral/tabasom/cropped/augmented/39_l.jpg
# ./images/lateral/tabasom/cropped/augmented/39_t.jpg
# ./images/lateral/tabasom/cropped/augmented/39_b.jpg
# ./images/lateral/tabasom/cropped/augmented/4_r.jpg
# ./images/lateral/tabasom/cropped/augmented/4_l.jpg
# ./images/lateral/tabasom/cropped/augmented/4_t.jpg
# ./images/lateral/tabasom/cropped/augmented/4_b.jpg
# ./images/lateral/tabasom/cropped/augmented/40_r.jpg
# ./images/lateral/tabasom/cropped/augmented/40_l.jpg
# ./images/lateral/tabasom/cropped/augmented/40_t.jpg
# ./images/lateral/tabasom/cropped/augmented/40_b.jpg
# ./images/lateral/tabasom/cropped/augmented/41_r.jpg
# ./images/lateral/tabasom/cropped/augmented/41_l.jpg
# ./images/lateral/tabasom/cropped/augmented/41_t.jpg
# ./images/lateral/tabasom/cropped/augmented/41_b.jpg
# ./images/lateral/tabasom/cropped/augmented/42_r.jpg
# ./images/lateral/tabasom/cropped/augmented/42_l.jpg
# ./images/lateral/tabasom/cropped/augmented/42_t.jpg
# ./images/lateral/tabasom/cropped/augmented/42_b.jpg
# ./images/lateral/tabasom/cropped/augmented/43_r.jpg
# ./images/lateral/tabasom/cropped/augmented/43_l.jpg
# ./images/lateral/tabasom/cropped/augmented/43_t.jpg
# ./images/lateral/tabasom/cropped/augmented/43_b.jpg
# ./images/lateral/tabasom/cropped/augmented/44_r.jpg
# ./images/lateral/tabasom/cropped/augmented/44_l.jpg
# ./images/lateral/tabasom/cropped/augmented/44_t.jpg
# ./images/lateral/tabasom/cropped/augmented/44_b.jpg
# ./images/lateral/tabasom/cropped/augmented/45_r.jpg
# ./images/lateral/tabasom/cropped/augmented/45_l.jpg
# ./images/lateral/tabasom/cropped/augmented/45_t.jpg
# ./images/lateral/tabasom/cropped/augmented/45_b.jpg
# ./images/lateral/tabasom/cropped/augmented/46_r.jpg
# ./images/lateral/tabasom/cropped/augmented/46_l.jpg
# ./images/lateral/tabasom/cropped/augmented/46_t.jpg
# ./images/lateral/tabasom/cropped/augmented/46_b.jpg
# ./images/lateral/tabasom/cropped/augmented/47_r.jpg
# ./images/lateral/tabasom/cropped/augmented/47_l.jpg
# ./images/lateral/tabasom/cropped/augmented/47_t.jpg
# ./images/lateral/tabasom/cropped/augmented/47_b.jpg
# ./images/lateral/tabasom/cropped/augmented/48_r.jpg
# ./images/lateral/tabasom/cropped/augmented/48_l.jpg
# ./images/lateral/tabasom/cropped/augmented/48_t.jpg
# ./images/lateral/tabasom/cropped/augmented/48_b.jpg
# ./images/lateral/tabasom/cropped/augmented/49_r.jpg
# ./images/lateral/tabasom/cropped/augmented/49_l.jpg
# ./images/lateral/tabasom/cropped/augmented/49_t.jpg
# ./images/lateral/tabasom/cropped/augmented/49_b.jpg
# ./images/lateral/tabasom/cropped/augmented/5_r.jpg
# ./images/lateral/tabasom/cropped/augmented/5_l.jpg
# ./images/lateral/tabasom/cropped/augmented/5_t.jpg
# ./images/lateral/tabasom/cropped/augmented/5_b.jpg
# ./images/lateral/tabasom/cropped/augmented/50_r.jpg
# ./images/lateral/tabasom/cropped/augmented/50_l.jpg
# ./images/lateral/tabasom/cropped/augmented/50_t.jpg
# ./images/lateral/tabasom/cropped/augmented/50_b.jpg
# ./images/lateral/tabasom/cropped/augmented/51_r.jpg
# ./images/lateral/tabasom/cropped/augmented/51_l.jpg
# ./images/lateral/tabasom/cropped/augmented/51_t.jpg
# ./images/lateral/tabasom/cropped/augmented/51_b.jpg
# ./images/lateral/tabasom/cropped/augmented/52_r.jpg
# ./images/lateral/tabasom/cropped/augmented/52_l.jpg
# ./images/lateral/tabasom/cropped/augmented/52_t.jpg
# ./images/lateral/tabasom/cropped/augmented/52_b.jpg
# ./images/lateral/tabasom/cropped/augmented/53_r.jpg
# ./images/lateral/tabasom/cropped/augmented/53_l.jpg
# ./images/lateral/tabasom/cropped/augmented/53_t.jpg
# ./images/lateral/tabasom/cropped/augmented/53_b.jpg
# ./images/lateral/tabasom/cropped/augmented/54_r.jpg
# ./images/lateral/tabasom/cropped/augmented/54_l.jpg
# ./images/lateral/tabasom/cropped/augmented/54_t.jpg
# ./images/lateral/tabasom/cropped/augmented/54_b.jpg
# ./images/lateral/tabasom/cropped/augmented/55_r.jpg
# ./images/lateral/tabasom/cropped/augmented/55_l.jpg
# ./images/lateral/tabasom/cropped/augmented/55_t.jpg
# ./images/lateral/tabasom/cropped/augmented/55_b.jpg
# ./images/lateral/tabasom/cropped/augmented/56_r.jpg
# ./images/lateral/tabasom/cropped/augmented/56_l.jpg
# ./images/lateral/tabasom/cropped/augmented/56_t.jpg
# ./images/lateral/tabasom/cropped/augmented/56_b.jpg
# ./images/lateral/tabasom/cropped/augmented/56a_r.jpg
# ./images/lateral/tabasom/cropped/augmented/56a_l.jpg
# ./images/lateral/tabasom/cropped/augmented/56a_t.jpg
# ./images/lateral/tabasom/cropped/augmented/56a_b.jpg
# ./images/lateral/tabasom/cropped/augmented/57_r.jpg
# ./images/lateral/tabasom/cropped/augmented/57_l.jpg
# ./images/lateral/tabasom/cropped/augmented/57_t.jpg
# ./images/lateral/tabasom/cropped/augmented/57_b.jpg
# ./images/lateral/tabasom/cropped/augmented/57a_r.jpg
# ./images/lateral/tabasom/cropped/augmented/57a_l.jpg
# ./images/lateral/tabasom/cropped/augmented/57a_t.jpg
# ./images/lateral/tabasom/cropped/augmented/57a_b.jpg
# ./images/lateral/tabasom/cropped/augmented/58_r.jpg
# ./images/lateral/tabasom/cropped/augmented/58_l.jpg
# ./images/lateral/tabasom/cropped/augmented/58_t.jpg
# ./images/lateral/tabasom/cropped/augmented/58_b.jpg
# ./images/lateral/tabasom/cropped/augmented/58a_r.jpg
# ./images/lateral/tabasom/cropped/augmented/58a_l.jpg
# ./images/lateral/tabasom/cropped/augmented/58a_t.jpg
# ./images/lateral/tabasom/cropped/augmented/58a_b.jpg
# ./images/lateral/tabasom/cropped/augmented/58b_r.jpg
# ./images/lateral/tabasom/cropped/augmented/58b_l.jpg
# ./images/lateral/tabasom/cropped/augmented/58b_t.jpg
# ./images/lateral/tabasom/cropped/augmented/58b_b.jpg
# ./images/lateral/tabasom/cropped/augmented/58c_r.jpg
# ./images/lateral/tabasom/cropped/augmented/58c_l.jpg
# ./images/lateral/tabasom/cropped/augmented/58c_t.jpg
# ./images/lateral/tabasom/cropped/augmented/58c_b.jpg
# ./images/lateral/tabasom/cropped/augmented/58d_r.jpg
# ./images/lateral/tabasom/cropped/augmented/58d_l.jpg
# ./images/lateral/tabasom/cropped/augmented/58d_t.jpg
# ./images/lateral/tabasom/cropped/augmented/58d_b.jpg
# ./images/lateral/tabasom/cropped/augmented/58e_r.jpg
# ./images/lateral/tabasom/cropped/augmented/58e_l.jpg
# ./images/lateral/tabasom/cropped/augmented/58e_t.jpg
# ./images/lateral/tabasom/cropped/augmented/58e_b.jpg
# ./images/lateral/tabasom/cropped/augmented/58f_r.jpg
# ./images/lateral/tabasom/cropped/augmented/58f_l.jpg
# ./images/lateral/tabasom/cropped/augmented/58f_t.jpg
# ./images/lateral/tabasom/cropped/augmented/58f_b.jpg
# ./images/lateral/tabasom/cropped/augmented/58g_r.jpg
# ./images/lateral/tabasom/cropped/augmented/58g_l.jpg
# ./images/lateral/tabasom/cropped/augmented/58g_t.jpg
# ./images/lateral/tabasom/cropped/augmented/58g_b.jpg
# ./images/lateral/tabasom/cropped/augmented/58h_r.jpg
# ./images/lateral/tabasom/cropped/augmented/58h_l.jpg
# ./images/lateral/tabasom/cropped/augmented/58h_t.jpg
# ./images/lateral/tabasom/cropped/augmented/58h_b.jpg
# ./images/lateral/tabasom/cropped/augmented/59_r.jpg
# ./images/lateral/tabasom/cropped/augmented/59_l.jpg
# ./images/lateral/tabasom/cropped/augmented/59_t.jpg
# ./images/lateral/tabasom/cropped/augmented/59_b.jpg
# ./images/lateral/tabasom/cropped/augmented/59a_r.jpg
# ./images/lateral/tabasom/cropped/augmented/59a_l.jpg
# ./images/lateral/tabasom/cropped/augmented/59a_t.jpg
# ./images/lateral/tabasom/cropped/augmented/59a_b.jpg
# ./images/lateral/tabasom/cropped/augmented/6_r.jpg
# ./images/lateral/tabasom/cropped/augmented/6_l.jpg
# ./images/lateral/tabasom/cropped/augmented/6_t.jpg
# ./images/lateral/tabasom/cropped/augmented/6_b.jpg
# ./images/lateral/tabasom/cropped/augmented/60_r.jpg
# ./images/lateral/tabasom/cropped/augmented/60_l.jpg
# ./images/lateral/tabasom/cropped/augmented/60_t.jpg
# ./images/lateral/tabasom/cropped/augmented/60_b.jpg
# ./images/lateral/tabasom/cropped/augmented/61_r.jpg
# ./images/lateral/tabasom/cropped/augmented/61_l.jpg
# ./images/lateral/tabasom/cropped/augmented/61_t.jpg
# ./images/lateral/tabasom/cropped/augmented/61_b.jpg
# ./images/lateral/tabasom/cropped/augmented/61a_r.jpg
# ./images/lateral/tabasom/cropped/augmented/61a_l.jpg
# ./images/lateral/tabasom/cropped/augmented/61a_t.jpg
# ./images/lateral/tabasom/cropped/augmented/61a_b.jpg
# ./images/lateral/tabasom/cropped/augmented/7_r.jpg
# ./images/lateral/tabasom/cropped/augmented/7_l.jpg
# ./images/lateral/tabasom/cropped/augmented/7_t.jpg
# ./images/lateral/tabasom/cropped/augmented/7_b.jpg
# ./images/lateral/tabasom/cropped/augmented/8_r.jpg
# ./images/lateral/tabasom/cropped/augmented/8_l.jpg
# ./images/lateral/tabasom/cropped/augmented/8_t.jpg
# ./images/lateral/tabasom/cropped/augmented/8_b.jpg
# ./images/lateral/tabasom/cropped/augmented/9_r.jpg
# ./images/lateral/tabasom/cropped/augmented/9_l.jpg
# ./images/lateral/tabasom/cropped/augmented/9_t.jpg
# ./images/lateral/tabasom/cropped/augmented/9_b.jpg

# %%
augment_rotate_ds(img_org_path1, img_new_path1, 0.2, 0.13)

# %%
img_org_path2 = './images/lateral/online/cropped/manual_augmented'
img_new_path2 = './images/lateral/online/cropped/manual_augmented/rotated'

img_org_path3 = './images/lateral/online/cropped/small/manual_augmented'
img_new_path3 = './images/lateral/online/cropped/small/manual_augmented/rotated'

rotate_ds(img_org_path2, img_new_path2)
rotate_ds(img_org_path3, img_new_path3)
# Out:
# ./images/lateral/online/cropped/manual_augmented/rotated/10a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/10b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/10c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/10d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/11a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/11b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/11c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/11d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/12a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/12b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/12c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/12d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/13a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/14a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/14b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/15a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/15b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/16a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/16b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/16c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/16d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/17a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/17b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/17c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/17d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/18a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/18b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/18c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/18d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/19a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/19b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/19c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/19d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/1a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/1b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/1c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/1d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/20a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/20b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/20c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/20d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/21a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/21b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/21c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/21d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/22a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/22b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/24a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/24b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/25a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/25b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/25c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/25d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/26a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/26b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/26c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/26d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/28a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/28b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/28c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/28d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/2a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/2b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/2c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/2d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/30a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/30b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/30c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/30d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/34a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/34b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/34c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/34d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/35a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/35b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/35c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/35d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/36a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/36b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/37a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/37b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/37c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/37d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/37f_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/37g_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/37h_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/38a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/38b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/38c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/38d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/3a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/3b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/3c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/3d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/40a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/40b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/40c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/40d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/41a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/41b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/41c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/41d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/42a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/42b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/42c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/42d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/44a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/44b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/44c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/44d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/45a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/45b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/45c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/45d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/46a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/46b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/46c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/46d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/47a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/47b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/47c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/47d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/47f_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/47g_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/49a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/49b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/4a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/4b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/50a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/50b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/50c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/50d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/51a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/51b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/51c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/51d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/51f_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/51g_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/51h_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/51i_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/53a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/53b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/53c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/53d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/53e_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/54a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/54b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/55a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/55b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/55c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/55d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/56a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/56b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/56c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/56d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/57a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/57b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/57c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/57d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/5a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/5b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/5c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/5d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/6a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/6b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/8a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/8b_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/8c_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/8d_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/8f_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/8g_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/9a_r_flip.jpg
# ./images/lateral/online/cropped/manual_augmented/rotated/9b_r_flip.jpg
# ./images/lateral/online/cropped/small/manual_augmented/rotated/23a_r_flip.jpg
# ./images/lateral/online/cropped/small/manual_augmented/rotated/23b_r_flip.jpg
# ./images/lateral/online/cropped/small/manual_augmented/rotated/27a_r_flip.jpg
# ./images/lateral/online/cropped/small/manual_augmented/rotated/27b_r_flip.jpg
# ./images/lateral/online/cropped/small/manual_augmented/rotated/27c_r_flip.jpg
# ./images/lateral/online/cropped/small/manual_augmented/rotated/27d_r_flip.jpg
# ./images/lateral/online/cropped/small/manual_augmented/rotated/31b_r_flip.jpg
# ./images/lateral/online/cropped/small/manual_augmented/rotated/32b_r_flip.jpg
# ./images/lateral/online/cropped/small/manual_augmented/rotated/33a_r_flip.jpg
# ./images/lateral/online/cropped/small/manual_augmented/rotated/33c_r_flip.jpg
# ./images/lateral/online/cropped/small/manual_augmented/rotated/33d_r_flip.jpg
# ./images/lateral/online/cropped/small/manual_augmented/rotated/39a_r_flip.jpg
# ./images/lateral/online/cropped/small/manual_augmented/rotated/39b_r_flip.jpg
# ./images/lateral/online/cropped/small/manual_augmented/rotated/39c_r_flip.jpg
# ./images/lateral/online/cropped/small/manual_augmented/rotated/39d_r_flip.jpg
# ./images/lateral/online/cropped/small/manual_augmented/rotated/52a_r_flip.jpg
# ./images/lateral/online/cropped/small/manual_augmented/rotated/52b_r_flip.jpg
# ./images/lateral/online/cropped/small/manual_augmented/rotated/52c_r_flip.jpg
# ./images/lateral/online/cropped/small/manual_augmented/rotated/52d_r_flip.jpg

# %% [markdown]
# Optional renaming and display

# %%
import re

img_org_pathN  = './images/lateral/online/cropped/small/manual_augmented/'
img_new_pathN = './images/lateral/online/cropped/small/manual_augmented/'




files_list = [f for f in os.listdir(img_org_pathN) if isfile(join(img_org_pathN, f))]

for f in files_list:
    new_name = os.path.splitext(f)[0]
    match = re.match(r"([0-9]+)([a-z,_]+)", new_name, re.I)
    if match:
        items = match.groups()

    
    
    new_name_w = img_new_pathN + items[0] + '_'+ items[1] + '.jpg'
    print(f, new_name_w)
    
    os.rename(img_org_pathN + f, new_name_w)
# Out:
# 23a.jpg ./images/lateral/online/cropped/small/manual_augmented/23_a.jpg
# 23b.jpg ./images/lateral/online/cropped/small/manual_augmented/23_b.jpg
# 27a.jpg ./images/lateral/online/cropped/small/manual_augmented/27_a.jpg
# 27b.jpg ./images/lateral/online/cropped/small/manual_augmented/27_b.jpg
# 27c.jpg ./images/lateral/online/cropped/small/manual_augmented/27_c.jpg
# 27d.jpg ./images/lateral/online/cropped/small/manual_augmented/27_d.jpg
# 31b.jpg ./images/lateral/online/cropped/small/manual_augmented/31_b.jpg
# 32b.jpg ./images/lateral/online/cropped/small/manual_augmented/32_b.jpg
# 33a.jpg ./images/lateral/online/cropped/small/manual_augmented/33_a.jpg
# 33c.jpg ./images/lateral/online/cropped/small/manual_augmented/33_c.jpg
# 33d.jpg ./images/lateral/online/cropped/small/manual_augmented/33_d.jpg
# 39a.jpg ./images/lateral/online/cropped/small/manual_augmented/39_a.jpg
# 39b.jpg ./images/lateral/online/cropped/small/manual_augmented/39_b.jpg
# 39c.jpg ./images/lateral/online/cropped/small/manual_augmented/39_c.jpg
# 39d.jpg ./images/lateral/online/cropped/small/manual_augmented/39_d.jpg
# 52a.jpg ./images/lateral/online/cropped/small/manual_augmented/52_a.jpg
# 52b.jpg ./images/lateral/online/cropped/small/manual_augmented/52_b.jpg
# 52c.jpg ./images/lateral/online/cropped/small/manual_augmented/52_c.jpg
# 52d.jpg ./images/lateral/online/cropped/small/manual_augmented/52_d.jpg

# %%
fx, plots = plt.subplots(2, 3, figsize=(20,10))

plots[0][0].set_title("Orignal Image")
plots[0][0].imshow(img)

plots[0][1].set_title("shifted_r Image")
plots[0][1].imshow(img_new_r)

plots[0][2].set_title("shifted_l Image")
plots[0][2].imshow(img_new_l)


plots[1][0].set_title("shifted_t Image")
plots[1][0].imshow(img_new_t)

plots[1][1].set_title("shifted_b Image")
plots[1][1].imshow(img_new_b)
